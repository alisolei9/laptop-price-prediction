# %% [markdown]
# # Decision Tree Regression
#
# In this notebook we train our second machine learning model using a Decision Tree Regressor and compare its performance with the Linear Regression baseline.

# %%
from pathlib import Path
import sys

import pandas as pd

from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score,
)

# %%
PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

# %%
from src.data_loader import load_data
from src.preprocessing import clean_data
from src.feature_engineering import engineer_features
from src.encoding import encode_features
from src.split_data import split_data

# %% [markdown]
# ## Load and Prepare Dataset

# %%
df = load_data()

df = clean_data(df)

df = engineer_features(df)

df = encode_features(df)

X_train, X_test, y_train, y_test = split_data(df)

# %%
print("X_train :", X_train.shape)
print("X_test  :", X_test.shape)

print("y_train :", y_train.shape)
print("y_test  :", y_test.shape)
# Out:
# X_train : (1020, 71)
# X_test  : (255, 71)
# y_train : (1020,)
# y_test  : (255,)

# %% [markdown]
# ## Train Decision Tree Model

# %%
tree = DecisionTreeRegressor(
    random_state=42
)

# %%
tree.fit(
    X_train,
    y_train
)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
y_pred = tree.predict(X_test)

# %%
comparison = pd.DataFrame(
    {
        "Actual Price": y_test,
        "Predicted Price": y_pred,
    }
)

comparison.head(10)
# Out:
#       Actual Price  Predicted Price
# 1179        650.00           685.00
# 342         716.00           979.00
# 649        1584.00          1650.00
# 772        1020.00           915.00
# 803        1749.00          2250.68
# 358         557.37           638.99
# 44          999.00          1770.00
# 231         330.00           349.00
# 618        2267.86          1819.00
# 43          682.00           805.00

# %% [markdown]
# ## Evaluate Decision Tree

# %%
mae = mean_absolute_error(
    y_test,
    y_pred
)

mse = mean_squared_error(
    y_test,
    y_pred
)

rmse = mse ** 0.5

r2 = r2_score(
    y_test,
    y_pred
)

# %%
print(f"MAE  : {mae:.2f}")
print(f"MSE  : {mse:.2f}")
print(f"RMSE : {rmse:.2f}")
print(f"R²   : {r2:.4f}")
# Out:
# MAE  : 245.36
# MSE  : 138297.00
# RMSE : 371.88
# R²   : 0.7214

# %% [markdown]
# ## Prediction Visualization

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,6))

plt.scatter(
    y_test,
    y_pred
)

plt.xlabel("Actual Price")

plt.ylabel("Predicted Price")

plt.title("Decision Tree Prediction")

plt.show()

# %%
residuals = y_test - y_pred

# %%
plt.figure(figsize=(8,6))

plt.scatter(
    y_pred,
    residuals
)

plt.axhline(
    y=0,
    color="red",
    linestyle="--"
)

plt.xlabel("Predicted Price")

plt.ylabel("Residual")

plt.title("Residual Plot")

plt.show()

# %% [markdown]
# ## Training Score vs Test Score

# %%
train_score = tree.score(
    X_train,
    y_train
)

test_score = tree.score(
    X_test,
    y_test
)

print(f"Train R² : {train_score:.4f}")

print(f"Test  R² : {test_score:.4f}")
# Out:
# Train R² : 0.9977
# Test  R² : 0.7214

# %% [markdown]
# ## Decision Tree With Regularization

# %%
tree_pruned = DecisionTreeRegressor(
    max_depth=8,
    min_samples_split=10,
    min_samples_leaf=5,
    random_state=42,
)

# %%
tree_pruned.fit(
    X_train,
    y_train
)
# Out:
# DecisionTreeRegressor(max_depth=8, min_samples_leaf=5, min_samples_split=10,
#                       random_state=42)

# %%
y_pred_pruned = tree_pruned.predict(
    X_test
)

# %%
train_score = tree_pruned.score(
    X_train,
    y_train
)

test_score = tree_pruned.score(
    X_test,
    y_test
)

print("Train :", train_score)

print("Test  :", test_score)
# Out:
# Train : 0.8478355911519114
# Test  : 0.7344899973332275

# %%
mae = mean_absolute_error(
    y_test,
    y_pred_pruned
)

rmse = mean_squared_error(
    y_test,
    y_pred_pruned
) ** 0.5

r2 = r2_score(
    y_test,
    y_pred_pruned
)

print("MAE :", mae)

print("RMSE:", rmse)

print("R² :", r2)
# Out:
# MAE : 237.65877051620336
# RMSE: 363.0193413138743
# R² : 0.7344899973332275

# %% [markdown]
# # Conclusion
#
# ## Linear Regression
#
# - Simple and interpretable.
# - Achieved the best overall performance on this dataset.
# - R² ≈ 0.79
#
# ---
#
# ## Decision Tree
#
# - Initial model suffered from overfitting.
# - Hyperparameter tuning reduced overfitting.
# - Test performance improved after regularization.
# - R² ≈ 0.73
#
# ---
#
# ## Final Observation
#
# For this dataset, Linear Regression generalized better than Decision Tree.

# %% [markdown]
# # End of Notebook
#
# In this notebook:
#
# - Trained a Decision Tree Regressor.
# - Evaluated the model using MAE, RMSE and R².
# - Detected overfitting.
# - Reduced overfitting using hyperparameter tuning.
# - Created a reusable evaluation module.
#
# The project is now ready for the Random Forest model.
