# %% [markdown]
# # Prediction System

# %%
from pathlib import Path
import sys

import pandas as pd

# %%
PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

# %%
from src.predict import predict_price

# %%
from src.data_loader import load_data
from src.preprocessing import clean_data
from src.feature_engineering import engineer_features
from src.encoding import encode_features

# %%
df = load_data()

df = clean_data(df)

df = engineer_features(df)

df = encode_features(df)

# %% [markdown]
# ## Sample Laptop

# %%
sample = df.drop(
    columns="price"
).iloc[[0]]

# %%
sample
# Out:
#    inches  cpu_frequency  ram  weight    ssd  hdd  flash_storage  hybrid  \
# 0    13.3            2.3    8    1.37  128.0  0.0            0.0     0.0
#
#    resolution_width  resolution_height  ...  cpu_family_Pentium  \
# 0              2560               1600  ...                   0
#
#    gpu_family_FirePro  gpu_family_GTX  gpu_family_HD Graphics  \
# 0                   0               0                       0
#
#    gpu_family_Iris Graphics  gpu_family_MX  gpu_family_Other  \
# 0                         1              0                 0
#
#    gpu_family_Quadro  gpu_family_Radeon  gpu_family_UHD Graphics
# 0                  0                  0                        0
#
# [1 rows x 71 columns]

# %% [markdown]
# ## Predict Price

# %%
prediction = predict_price(
    sample
)

prediction
# Out:
# array([1349.86679663])

# %%
print(
    f"Predicted Price : ${prediction[0]:.2f}"
)
# Out:
# Predicted Price : $1349.87

# %% [markdown]
# # Conclusion
#
# A prediction system was successfully created.
#
# The saved Gradient Boosting model was loaded without retraining and used to predict laptop prices from new input data.
#
# This notebook demonstrates how the trained model can be integrated into a real application.
