# %% [markdown]
# # Laptop Price Prediction Project Report

# %% [markdown]
# ## Project Overview
#
# This project aims to predict laptop prices using several machine learning regression algorithms.
#
# The complete pipeline includes:
#
# - Data exploration
# - Data cleaning
# - Feature engineering
# - Encoding
# - Train/Test split
# - Model training
# - Model comparison
# - Hyperparameter tuning
# - Final model selection
# - Model deployment preparation

# %% [markdown]
# ## Dataset
#
# The dataset contains laptop specifications including:
#
# - Company
# - RAM
# - CPU
# - GPU
# - SSD
# - HDD
# - Screen Resolution
# - Operating System
# - Weight
#
# Target variable:
#
# - Price

# %%
import pandas as pd

# %%
results = pd.DataFrame(
    {
        "Model": [
            "Linear Regression",
            "Decision Tree",
            "Random Forest",
            "Random Forest Tuned",
            "KNN",
            "SVR",
            "Gradient Boosting",
            "XGBoost",
            "LightGBM",
            "CatBoost",
        ],
        "MAE": [
            241.02,
            237.66,
            179.93,
            176.52,
            226.49,
            919.32,
            185.16,
            181.47,
            180.74,
            174.51,
        ],
        "RMSE": [
            326.27,
            363.02,
            268.42,
            262.20,
            353.64,
            649.83,
            253.31,
            262.39,
            290.55,
            254.08,
        ],
        "R2": [
            0.7855,
            0.7345,
            0.8548,
            0.8615,
            0.7480,
            -0.0296,
            0.8707,
            0.8613,
            0.8299,
            0.8699,
        ],
    }
)

results.sort_values("R2", ascending=False)
# Out:
#                  Model     MAE    RMSE      R2
# 6    Gradient Boosting  185.16  253.31  0.8707
# 9             CatBoost  174.51  254.08  0.8699
# 3  Random Forest Tuned  176.52  262.20  0.8615
# 7              XGBoost  181.47  262.39  0.8613
# 2        Random Forest  179.93  268.42  0.8548
# 8             LightGBM  180.74  290.55  0.8299
# 0    Linear Regression  241.02  326.27  0.7855
# 4                  KNN  226.49  353.64  0.7480
# 1        Decision Tree  237.66  363.02  0.7345
# 5                  SVR  919.32  649.83 -0.0296

# %% [markdown]
# ## Final Model
#
# Gradient Boosting achieved the highest R² score (0.8707).
#
# Although CatBoost achieved a lower MAE, Gradient Boosting provided the best overall balance between prediction accuracy and generalization.
#
# Therefore, Gradient Boosting was selected as the final production model.

# %% [markdown]
# ## Future Improvements
#
# Possible improvements include:
#
# - Collecting more training data
# - Trying deep learning models
# - Feature selection
# - Advanced hyperparameter optimization
# - Deploying the model using Streamlit

# %% [markdown]
# # Conclusion
#
# This project successfully developed a complete end-to-end laptop price prediction system.
#
# The project covers the full machine learning workflow from raw data to a deployable prediction model.
